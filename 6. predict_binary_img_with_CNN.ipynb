# %% [markdown]
# 먼저 이미지를 배열화 시켜주어야 한다.
#
# 그리고 여기 이미지에서 훈련 데이터, 테스트 데이터(사실상 검증 데이터)로 나눠준다.
#
# 이후 numpy 형태로 저장.

# %%
from PIL import Image
import os, glob, sys, numpy as np
from sklearn.model_selection import train_test_split
from keras.utils import np_utils

img_dir = './binary_img_data/imgs'
categories = ['Cat', 'Dog']
np_classes = len(categories)

image_w = 64
image_h = 64


pixel = image_h * image_w * 3

X = []
y = []

for idx, cat in enumerate(categories):
    img_dir_detail = img_dir + "/" + cat
    files = glob.glob(img_dir_detail+"/*.jpg")


    for i, f in enumerate(files):
        try:
            img = Image.open(f)
            img = img.convert("RGB")
            img = img.resize((image_w, image_h))
            data = np.asarray(img)
            #Y는 0 아니면 1이니까 idx값으로 넣는다.
            X.append(data)
            y.append(idx)
            if i % 300 == 0:
                print(cat, " : ", f)
        except:
            print(cat, str(i)+" 번째에서 에러 ")
X = np.array(X)
Y = np.array(y)


X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1)

xy = (X_train, X_test, Y_train, Y_test)
np.save("./numpy_data/binary_image_data.npy", xy)
# Out:
# C:\Users\leesoojin\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Cat  :  ./binary_img_data/imgs/Cat\0.jpg
# Cat  :  ./binary_img_data/imgs/Cat\10267.jpg
# Cat  :  ./binary_img_data/imgs/Cat\10537.jpg
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 80000 bytes but only got 0. Skipping tag 64640
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 65536 bytes but only got 0. Skipping tag 3
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 404094976 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 404619264 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 131072 bytes but only got 0. Skipping tag 3
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 425459712 bytes but only got 0. Skipping tag 4
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 1385474 bytes but only got 6833. Skipping tag 513
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 3846701056 bytes but only got 0. Skipping tag 2
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 3300917248 bytes but only got 0. Skipping tag 7
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 196867 bytes but only got 6833. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:756: UserWarning: Corrupt EXIF data.  Expecting to read 12 bytes but only got 8.
#   warnings.warn(str(msg))
# Cat  :  ./binary_img_data/imgs/Cat\10807.jpg
# Cat  :  ./binary_img_data/imgs/Cat\11077.jpg
# Cat  :  ./binary_img_data/imgs/Cat\11347.jpg
# Cat  :  ./binary_img_data/imgs/Cat\11617.jpg
# Cat  :  ./binary_img_data/imgs/Cat\11888.jpg
# Cat  :  ./binary_img_data/imgs/Cat\12157.jpg
# Cat  :  ./binary_img_data/imgs/Cat\12427.jpg
# Cat  :  ./binary_img_data/imgs/Cat\1465.jpg
# Cat  :  ./binary_img_data/imgs/Cat\1762.jpg
# Cat  :  ./binary_img_data/imgs/Cat\2058.jpg
# Cat  :  ./binary_img_data/imgs/Cat\2355.jpg
# Cat  :  ./binary_img_data/imgs/Cat\2652.jpg
# Cat  :  ./binary_img_data/imgs/Cat\2949.jpg
# Cat  :  ./binary_img_data/imgs/Cat\3245.jpg
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 18350080 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:756: UserWarning: Corrupt EXIF data.  Expecting to read 12 bytes but only got 6.
#   warnings.warn(str(msg))
# Cat  :  ./binary_img_data/imgs/Cat\3530.jpg
# Cat  :  ./binary_img_data/imgs/Cat\3800.jpg
# Cat  :  ./binary_img_data/imgs/Cat\4070.jpg
# Cat  :  ./binary_img_data/imgs/Cat\4340.jpg
# Cat  :  ./binary_img_data/imgs/Cat\4610.jpg
# Cat  :  ./binary_img_data/imgs/Cat\4881.jpg
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 307363840 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 307888128 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 328728576 bytes but only got 0. Skipping tag 4
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 1385474 bytes but only got 5357. Skipping tag 513
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 196867 bytes but only got 5357. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# Cat  :  ./binary_img_data/imgs/Cat\5150.jpg
# Cat  :  ./binary_img_data/imgs/Cat\5420.jpg
# Cat  :  ./binary_img_data/imgs/Cat\5691.jpg
# Cat  :  ./binary_img_data/imgs/Cat\5961.jpg
# Cat  :  ./binary_img_data/imgs/Cat\6230.jpg
# Cat  :  ./binary_img_data/imgs/Cat\6500.jpg
# Cat  :  ./binary_img_data/imgs/Cat\6772.jpg
# Cat  :  ./binary_img_data/imgs/Cat\7041.jpg
# Cat  :  ./binary_img_data/imgs/Cat\7311.jpg
# Cat  :  ./binary_img_data/imgs/Cat\7582.jpg
# Cat  :  ./binary_img_data/imgs/Cat\7852.jpg
# Cat  :  ./binary_img_data/imgs/Cat\8121.jpg
# Cat  :  ./binary_img_data/imgs/Cat\8392.jpg
# Cat  :  ./binary_img_data/imgs/Cat\8662.jpg
# Cat  :  ./binary_img_data/imgs/Cat\8932.jpg
# Cat  :  ./binary_img_data/imgs/Cat\9201.jpg
# Cat  :  ./binary_img_data/imgs/Cat\9472.jpg
# Cat  :  ./binary_img_data/imgs/Cat\9742.jpg
# Dog  :  ./binary_img_data/imgs/Dog\0.jpg
# Dog  :  ./binary_img_data/imgs/Dog\10270.jpg
# Dog  :  ./binary_img_data/imgs/Dog\10543.jpg
# Dog  :  ./binary_img_data/imgs/Dog\10816.jpg
# Dog  :  ./binary_img_data/imgs/Dog\11089.jpg
# Dog  :  ./binary_img_data/imgs/Dog\11361.jpg
# Dog  :  ./binary_img_data/imgs/Dog\11634.jpg
# Dog 1875 번째에서 에러
# Dog  :  ./binary_img_data/imgs/Dog\11907.jpg
# Dog  :  ./binary_img_data/imgs/Dog\1218.jpg
# Dog  :  ./binary_img_data/imgs/Dog\12452.jpg
# Dog  :  ./binary_img_data/imgs/Dog\1498.jpg
# Dog  :  ./binary_img_data/imgs/Dog\1798.jpg
# Dog  :  ./binary_img_data/imgs/Dog\2098.jpg
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 262146 bytes but only got 0. Skipping tag 2
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 262151 bytes but only got 0. Skipping tag 56
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:756: UserWarning: Corrupt EXIF data.  Expecting to read 12 bytes but only got 0.
#   warnings.warn(str(msg))
# Dog  :  ./binary_img_data/imgs/Dog\2398.jpg
# Dog  :  ./binary_img_data/imgs/Dog\2698.jpg
# Dog  :  ./binary_img_data/imgs/Dog\2984.jpg
# Dog  :  ./binary_img_data/imgs/Dog\3256.jpg
# Dog  :  ./binary_img_data/imgs/Dog\3529.jpg
# Dog  :  ./binary_img_data/imgs/Dog\3801.jpg
# Dog  :  ./binary_img_data/imgs/Dog\4073.jpg
# Dog  :  ./binary_img_data/imgs/Dog\4346.jpg
# Dog  :  ./binary_img_data/imgs/Dog\4619.jpg
# Dog  :  ./binary_img_data/imgs/Dog\4891.jpg
# Dog  :  ./binary_img_data/imgs/Dog\5163.jpg
# Dog  :  ./binary_img_data/imgs/Dog\5436.jpg
# Dog  :  ./binary_img_data/imgs/Dog\5709.jpg
# Dog  :  ./binary_img_data/imgs/Dog\5981.jpg
# Dog  :  ./binary_img_data/imgs/Dog\6253.jpg
# Dog  :  ./binary_img_data/imgs/Dog\6526.jpg
# Dog  :  ./binary_img_data/imgs/Dog\6799.jpg
# Dog  :  ./binary_img_data/imgs/Dog\7070.jpg
# Dog  :  ./binary_img_data/imgs/Dog\7343.jpg
# Dog  :  ./binary_img_data/imgs/Dog\7616.jpg
# Dog  :  ./binary_img_data/imgs/Dog\7889.jpg
# Dog  :  ./binary_img_data/imgs/Dog\8160.jpg
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 6553600 bytes but only got 0. Skipping tag 49
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 1050744 bytes but only got 4951. Skipping tag 51
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 293339136 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 293863424 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 3368026112 bytes but only got 0. Skipping tag 7
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 134479872 bytes but only got 0. Skipping tag 7
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 295698432 bytes but only got 0. Skipping tag 10
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 296222720 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 14745600 bytes but only got 0. Skipping tag 4
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 25624576 bytes but only got 0. Skipping tag 4
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 317718528 bytes but only got 4956. Skipping tag 4
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 131073 bytes but only got 4952. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 393216 bytes but only got 0. Skipping tag 3
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 287178752 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 287703040 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 524288 bytes but only got 0. Skipping tag 4
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 286654464 bytes but only got 4956. Skipping tag 4
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:756: UserWarning: Corrupt EXIF data.  Expecting to read 12 bytes but only got 2.
#   warnings.warn(str(msg))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 209715200 bytes but only got 0. Skipping tag 48
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 52428800 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 6468665344 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 1050744 bytes but only got 7027. Skipping tag 48
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 422313984 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 422838272 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 428867584 bytes but only got 0. Skipping tag 10
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 429391872 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 2031616 bytes but only got 0. Skipping tag 3
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 429916160 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 21299200 bytes but only got 0. Skipping tag 4
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 24313856 bytes but only got 0. Skipping tag 4
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 453771264 bytes but only got 7032. Skipping tag 4
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 131073 bytes but only got 7028. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 416415744 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 416940032 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 415825920 bytes but only got 7032. Skipping tag 4
#   " Skipping tag %s" % (size, len(data), tag))
# Dog  :  ./binary_img_data/imgs/Dog\8433.jpg
# Dog  :  ./binary_img_data/imgs/Dog\8706.jpg
# Dog  :  ./binary_img_data/imgs/Dog\8979.jpg
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 32 bytes but only got 0. Skipping tag 270
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 5 bytes but only got 0. Skipping tag 271
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 272
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 282
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 8 bytes but only got 0. Skipping tag 283
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 20 bytes but only got 0. Skipping tag 306
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:739: UserWarning: Possibly corrupt EXIF data.  Expecting to read 48 bytes but only got 0. Skipping tag 532
#   " Skipping tag %s" % (size, len(data), tag))
# C:\Users\leesoojin\Anaconda3\lib\site-packages\PIL\TiffImagePlugin.py:756: UserWarning: Corrupt EXIF data.  Expecting to read 2 bytes but only got 0.
#   warnings.warn(str(msg))
# Dog  :  ./binary_img_data/imgs/Dog\9251.jpg
# Dog  :  ./binary_img_data/imgs/Dog\9524.jpg
# Dog  :  ./binary_img_data/imgs/Dog\9797.jpg

# %% [markdown]
# 이제 훈련을 시작한다. 저장한 numpy 값을 가지고 와서 컨볼루션 망을 구축한다.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt
import keras.backend.tensorflow_backend as K

X_train, X_test, y_train, y_test = np.load('./numpy_data/binary_image_data.npy')
print(X_train.shape)
print(X_train.shape[0])
print(np.bincount(y_train))
print(np.bincount(y_test))
# Out:
# (22056, 64, 64, 3)
# 22056
# [11094 10962]
# [1191 1260]

# %%
image_w = 64
image_h = 64
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255


with K.tf_ops.device('/device:GPU:0'):
    model = Sequential()
    model.add(Conv2D(32, (3,3), padding="same", input_shape=X_train.shape[1:], activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Conv2D(32, (3,3), padding="same", activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))

    model.add(Conv2D(64, (3,3), padding="same", activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Conv2D(64, (3,3), padding="same", activation="relu"))
    model.add(MaxPooling2D(pool_size=(2,2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(256, activation="relu"))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation="sigmoid"))
    
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    model_dir = './model'
    if not os.path.exists(model_dir):
        os.mkdir(model_dir)
    model_path = model_dir + "/dog_cat_classify.model"
    
    checkpoint = ModelCheckpoint(filepath=model_path, monitor='val_loss', verbose=1, save_best_only=True)
    early_stopping = EarlyStopping(monitor='val_loss', patience=7)

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 64, 64, 32)        896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 328,225
# Trainable params: 328,225
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, batch_size=64, epochs=100, validation_split=0.15, callbacks=[checkpoint, early_stopping])
# Out:
# Train on 18747 samples, validate on 3309 samples
# Epoch 1/100
# 18747/18747 [==============================] - 9s 480us/step - loss: 0.6535 - acc: 0.5976 - val_loss: 0.5828 - val_acc: 0.6878
#
# Epoch 00001: val_loss improved from inf to 0.58284, saving model to ./model/dog_cat_classify.model
# Epoch 2/100
# 18747/18747 [==============================] - 5s 258us/step - loss: 0.5458 - acc: 0.7248 - val_loss: 0.4519 - val_acc: 0.7875
#
# Epoch 00002: val_loss improved from 0.58284 to 0.45193, saving model to ./model/dog_cat_classify.model
# Epoch 3/100
# 18747/18747 [==============================] - 5s 257us/step - loss: 0.4688 - acc: 0.7803 - val_loss: 0.4365 - val_acc: 0.8005
#
# Epoch 00003: val_loss improved from 0.45193 to 0.43645, saving model to ./model/dog_cat_classify.model
# Epoch 4/100
# 18747/18747 [==============================] - 5s 256us/step - loss: 0.4099 - acc: 0.8158 - val_loss: 0.3824 - val_acc: 0.8290
#
# Epoch 00004: val_loss improved from 0.43645 to 0.38235, saving model to ./model/dog_cat_classify.model
# Epoch 5/100
# 18747/18747 [==============================] - 5s 253us/step - loss: 0.3696 - acc: 0.8354 - val_loss: 0.3514 - val_acc: 0.8471
#
# Epoch 00005: val_loss improved from 0.38235 to 0.35142, saving model to ./model/dog_cat_classify.model
# Epoch 6/100
# 18747/18747 [==============================] - 5s 253us/step - loss: 0.3396 - acc: 0.8506 - val_loss: 0.3485 - val_acc: 0.8477
#
# Epoch 00006: val_loss improved from 0.35142 to 0.34848, saving model to ./model/dog_cat_classify.model
# Epoch 7/100
# 18747/18747 [==============================] - 5s 253us/step - loss: 0.3146 - acc: 0.8647 - val_loss: 0.3215 - val_acc: 0.8534
#
# Epoch 00007: val_loss improved from 0.34848 to 0.32153, saving model to ./model/dog_cat_classify.model
# Epoch 8/100
# 18747/18747 [==============================] - 5s 256us/step - loss: 0.2959 - acc: 0.8730 - val_loss: 0.3429 - val_acc: 0.8489
#
# Epoch 00008: val_loss did not improve from 0.32153
# Epoch 9/100
# 18747/18747 [==============================] - 5s 253us/step - loss: 0.2719 - acc: 0.8860 - val_loss: 0.3596 - val_acc: 0.8344
#
# Epoch 00009: val_loss did not improve from 0.32153
# Epoch 10/100
# 18747/18747 [==============================] - 5s 252us/step - loss: 0.2641 - acc: 0.8865 - val_loss: 0.3158 - val_acc: 0.8604
#
# Epoch 00010: val_loss improved from 0.32153 to 0.31585, saving model to ./model/dog_cat_classify.model
# Epoch 11/100
# 18747/18747 [==============================] - 5s 252us/step - loss: 0.2454 - acc: 0.8964 - val_loss: 0.3352 - val_acc: 0.8501
#
# Epoch 00011: val_loss did not improve from 0.31585
# Epoch 12/100
# 18747/18747 [==============================] - 5s 251us/step - loss: 0.2316 - acc: 0.9034 - val_loss: 0.2955 - val_acc: 0.8707
#
# Epoch 00012: val_loss improved from 0.31585 to 0.29551, saving model to ./model/dog_cat_classify.model
# Epoch 13/100
# 18747/18747 [==============================] - 5s 251us/step - loss: 0.2199 - acc: 0.9087 - val_loss: 0.2893 - val_acc: 0.8710
#
# Epoch 00013: val_loss improved from 0.29551 to 0.28931, saving model to ./model/dog_cat_classify.model
# Epoch 14/100
# 18747/18747 [==============================] - 5s 256us/step - loss: 0.2107 - acc: 0.9129 - val_loss: 0.3070 - val_acc: 0.8731
#
# Epoch 00014: val_loss did not improve from 0.28931
# Epoch 15/100
# 18747/18747 [==============================] - 5s 251us/step - loss: 0.1966 - acc: 0.9178 - val_loss: 0.3023 - val_acc: 0.8731
#
# Epoch 00015: val_loss did not improve from 0.28931
# Epoch 16/100
# 18747/18747 [==============================] - 5s 251us/step - loss: 0.1844 - acc: 0.9231 - val_loss: 0.2875 - val_acc: 0.8749
#
# Epoch 00016: val_loss improved from 0.28931 to 0.28753, saving model to ./model/dog_cat_classify.model
# Epoch 17/100
# 18747/18747 [==============================] - 5s 256us/step - loss: 0.1709 - acc: 0.9301 - val_loss: 0.3019 - val_acc: 0.8728
#
# Epoch 00017: val_loss did not improve from 0.28753
# Epoch 18/100
# 18747/18747 [==============================] - 5s 251us/step - loss: 0.1689 - acc: 0.9308 - val_loss: 0.3354 - val_acc: 0.8758
#
# Epoch 00018: val_loss did not improve from 0.28753
# Epoch 19/100
# 18747/18747 [==============================] - 5s 251us/step - loss: 0.1600 - acc: 0.9357 - val_loss: 0.3402 - val_acc: 0.8728
#
# Epoch 00019: val_loss did not improve from 0.28753
# Epoch 20/100
# 18747/18747 [==============================] - 5s 251us/step - loss: 0.1536 - acc: 0.9372 - val_loss: 0.3399 - val_acc: 0.8761 loss
#
# Epoch 00020: val_loss did not improve from 0.28753
# Epoch 21/100
# 18747/18747 [==============================] - 5s 251us/step - loss: 0.1521 - acc: 0.9403 - val_loss: 0.3176 - val_acc: 0.8707
#
# Epoch 00021: val_loss did not improve from 0.28753
# Epoch 22/100
# 18747/18747 [==============================] - 5s 252us/step - loss: 0.1417 - acc: 0.9406 - val_loss: 0.3122 - val_acc: 0.8755
#
# Epoch 00022: val_loss did not improve from 0.28753
# Epoch 23/100
# 18747/18747 [==============================] - 5s 251us/step - loss: 0.1424 - acc: 0.9423 - val_loss: 0.3405 - val_acc: 0.8713
#
# Epoch 00023: val_loss did not improve from 0.28753

# %%
print("정확도 : %.2f " %(model.evaluate(X_test, y_test)[1]))
# Out:
# 2451/2451 [==============================] - 0s 153us/step
# 정확도 : 0.88

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['loss', 'val_loss', 'acc', 'val_acc'], loc='upper left')
plt.show()

# %%
from PIL import Image
import os, glob, numpy as np
from keras.models import load_model

import tensorflow as tf

seed = 5
tf.set_random_seed(seed)
np.random.seed(seed)

caltech_dir = './binary_img_data/img_test'


image_w = 64
image_h = 64

pixels = image_h * image_w * 3

X = []
filenames = []
files = glob.glob(caltech_dir+"/*/*.*")
for i, f in enumerate(files):
    img = Image.open(f)
    img = img.convert("RGB")
    img = img.resize((image_w, image_h))
    data = np.asarray(img)

    filenames.append(f)
    X.append(data)


X = np.array(X)
X = X.astype(float) / 255
model = load_model('./model/dog_cat_classify.model')

prediction = model.predict(X)
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
cnt = 0
for i in prediction:
    if i >= 0.5: print("해당 " + filenames[cnt].split("\\")[1] + filenames[cnt].split("\\")[2] + "  이미지는 개 로 추정됩니다.")
    else : print("해당 " + filenames[cnt].split("\\")[1] + filenames[cnt].split("\\")[2] + "  이미지는 고양이 으로 추정됩니다.")
    cnt += 1
# Out:
# 해당 catcat103.jpg  이미지는 고양이 으로 추정됩니다.
# 해당 catcat11 - 복사본.jpg  이미지는 고양이 으로 추정됩니다.
# 해당 catcat15 - 복사본.jpg  이미지는 고양이 으로 추정됩니다.
# 해당 catcat22 - 복사본.jpg  이미지는 고양이 으로 추정됩니다.
# 해당 catcat27 - 복사본.jpg  이미지는 고양이 으로 추정됩니다.
# 해당 catcat30 - 복사본.jpg  이미지는 고양이 으로 추정됩니다.
# 해당 catcat31 - 복사본.jpg  이미지는 고양이 으로 추정됩니다.
# 해당 catcat37.jpg  이미지는 고양이 으로 추정됩니다.
# 해당 catcat4.jpg  이미지는 고양이 으로 추정됩니다.
# 해당 catcat40.jpg  이미지는 고양이 으로 추정됩니다.
# 해당 catcat48 - 복사본.jpg  이미지는 개 로 추정됩니다.
# 해당 catcat53 - 복사본.jpg  이미지는 고양이 으로 추정됩니다.
# 해당 catcat56 - 복사본.jpg  이미지는 개 로 추정됩니다.
# 해당 catcat67 - 복사본.jpg  이미지는 고양이 으로 추정됩니다.
# 해당 catcat69 - 복사본.jpg  이미지는 고양이 으로 추정됩니다.
# 해당 catcat70 - 복사본.jpg  이미지는 고양이 으로 추정됩니다.
# 해당 catcat70.jpg  이미지는 고양이 으로 추정됩니다.
# 해당 catcat72 - 복사본.jpg  이미지는 개 로 추정됩니다.
# 해당 catcat9.jpg  이미지는 개 로 추정됩니다.
# 해당 catcat99 - 복사본.jpg  이미지는 고양이 으로 추정됩니다.
# 해당 dog개1.PNG  이미지는 개 로 추정됩니다.
# 해당 dog개2.PNG  이미지는 고양이 으로 추정됩니다.
# 해당 dog개3.PNG  이미지는 개 로 추정됩니다.
# 해당 dog개4.PNG  이미지는 개 로 추정됩니다.
# 해당 dog개5.PNG  이미지는 개 로 추정됩니다.
